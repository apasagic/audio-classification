# %% [markdown]
# <a href="https://colab.research.google.com/github/apasagic/audio-classification/blob/main/Drum_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import librosa
import librosa.display
import os
import random
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

from keras.models import Sequential
from keras.layers import LSTM, SimpleRNN, Dense, Bidirectional, Dropout, TimeDistributed, Activation, Input, Reshape, Lambda, RepeatVector

from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import OneHotEncoder
# Out:
# Mounted at /content/drive

# %%
# Define constants
#SR = 22050
#DURATION = 1  # in seconds
WINDOW_SIZE = 0.025  # in seconds (100 ms)
HOP_SIZE = 0.05  # in seconds (50 ms)
N_FFT = 2048

# %%
# Load representative 4 samples of each drum category

file_path_kick = '/content/drive/My Drive/Drum_samples/kick/Bass Sample 1.wav'
file_path_overhead = '/content/drive/My Drive/Drum_samples/overheads/Overhead Sample 1.wav'
file_path_snare = '/content/drive/My Drive/Drum_samples/snare/Snare Sample 1.wav'
file_path_tom = '/content/drive/My Drive/Drum_samples/toms/Tom Sample 1.wav'

audio_kick, sr = librosa.load(file_path_kick,mono=True)
audio_overhead, sr = librosa.load(file_path_overhead, mono=True)
audio_snare, sr = librosa.load(file_path_snare, mono=True)
audio_tom, sr = librosa.load(file_path_tom, mono=True)

len_audio = len(audio_overhead)

# %%
fig, axs = plt.subplots(2, 2, figsize = (12,10))

# Plot the waveform (time domain)
#plt.figure(figsize=fig_size)
librosa.display.waveshow(audio_kick, sr=sr, ax = axs[0,0])
axs[0,0].set_title('Waveform Kick')
axs[0,0].set_xlabel('Time (s)')
axs[0,0].set_ylabel('Amplitude')
axs[0,0].grid(True)
#axs[0,0].set_xlim(0,0.1)

# Plot the waveform (time domain)
librosa.display.waveshow(audio_overhead, sr=sr, ax = axs[0,1])
axs[0,1].set_title('Waveform Overhead')
axs[0,1].set_xlabel('Time (s)')
axs[0,1].set_ylabel('Amplitude')
axs[0,1].grid(True)
#axs[0,1].set_xlim(0,0.1)

# Plot the waveform (time domain)
librosa.display.waveshow(audio_snare, sr=sr, ax = axs[1,0])
axs[1,0].set_title('Waveform Snare')
axs[1,0].set_xlabel('Time (s)')
axs[1,0].set_ylabel('Amplitude')
axs[1,0].grid(True)
#axs[1,0].set_xlim(0,0.1)

# Plot the waveform (time domain)
librosa.display.waveshow(audio_tom, sr=sr, ax = axs[1,1])
axs[1,1].set_title('Waveform Tom')
axs[1,1].set_xlabel('Time (s)')
axs[1,1].set_ylabel('Amplitude')
axs[1,1].grid(True)

# %%
N_FFT = 2048

# Compute the Short-Time Fourier Transform (STFT)
D = librosa.stft(audio_kick)
magnitude, phase = librosa.magphase(D)

# Convert magnitude to decibels
magnitude_db = librosa.amplitude_to_db(magnitude, ref=np.max)

# Plot the spectrogram of a Kick Drum (frequency domain)
plt.figure(figsize=(12, 4))
librosa.display.specshow(magnitude_db, sr=sr, x_axis='time', y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram Kick')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.show()

D = librosa.stft(audio_snare)
magnitude, phase = librosa.magphase(D)

# Convert magnitude to decibels
magnitude_db = librosa.amplitude_to_db(magnitude, ref=np.max)

# Plot the spectrogram of an Overhead (frequency domain)
plt.figure(figsize=(12, 4))
librosa.display.specshow(magnitude_db, sr=sr, x_axis='time', y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram Overhead')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.show()

# %%
# In this part, code itterates though a given folder structure, and makes a list
# of all the file names contained in the folder/subfolder structure.
# List is then randomized for later division into Train/Test dataset
#
# Wave files are loaded and converted into a STFT representation in decibel,
# and resulting array that has Tx timesample times 1025 frequency bins is
# transposed and concatenated vertically to be later used as input tensor for RNN.
#
# Similarly Y is added a target label for each instrument based on folder name
# This has to be repeated for each timestep to be used in unfolded RNN
# Optionally periods of silence can be added as fifth category 'None'

# Local path to drum sample dir
directory = "/content/drive/My Drive/Drum_samples/"

# Init file list
list_files = []

# Ammount of data to be used for testing
test_perc = 0.1

#Itterate thru folder structure and get a file name list
for root, dirs, files in os.walk(directory):
  for file in files:

    if file.endswith(".wav"):

      file_path = os.path.join(root, file)
      list_files.append(file_path)

# Randomize the file list
random.shuffle(list_files)

# Initialize the arrays to be filled later with actual values with one row of 0
# This is later to be deleted for dimension consistency

X_train = np.zeros((1, int(1+N_FFT/2) ))
X_test = np.zeros((1, int(1+N_FFT/2) ))

# Get number of files in total
len_list = len(list_files)

# Init target variable lists
y_train = []
y_train_plot = []
y_test = []

# Define minimum and maximum length for period of silence
sil_dur_min, sil_dur_max = 1,5

# Itterate thru file structure
for x, file_path in enumerate(list_files):

      # Load audio files
      audio, sr = librosa.load(file_path, mono=True)

      # Calculated STFT, and get corresponding magntiude spectrum in DB
      #stft = librosa.stft(audio[0:8000], n_fft=N_FFT, hop_length=int(HOP_SIZE * sr))
      stft = librosa.stft(audio[0:8000], n_fft=N_FFT)

      magnitude, phase = librosa.magphase(stft)
      magnitude_db = librosa.amplitude_to_db(magnitude, ref=np.max)

      # Get a label Y from a file name
      label = os.path.basename(os.path.dirname(file_path))  # Assuming each subdirectory represents a class

      # For first 80% files in the randomized list add to train set
      if(x <int(len_list*(1-test_perc))):

        # Append an array of Magnitudes_DB generated by STFT (transposed - columns = freq_bins)
        #X_train = np.vstack((X_train,np.sum(magnitude_db.T,axis=0)))
        X_train = np.vstack((X_train, magnitude_db.T))

        #Fix to generate folded network
        #y_train.append(label)

        # Append a label Y for each timestep in magnitude vector
        for i in range(magnitude_db.shape[1]):
           y_train_plot.append(label)
           y_train.append(label)
        # Uncomment for unfolded netwtork
        #   y_train.append(label)

        #Add random period of silence in length of 10-100 samples
        for j in range(random.randint(sil_dur_min, sil_dur_max)):
          X_train = np.vstack((X_train, -80*np.ones((1,magnitude_db.shape[0])) ))
          y_train.append('None')

      # For last 20 files in the randomized list add to test set
      else:

        # Append an array of Magnitudes_DB generated by STFT (transposed - columns = freq_bins)
        #X_test = np.vstack((X_test, magnitude_db.T))
        X_test = np.vstack((X_test,magnitude_db.T))
        #X_test = np.stack((X_test, magnitude_db.T),axis = 0)

        # Append a label Y for each timestep in magnitude vector
        #y_test.append(label)

        # Append a label Y for each timestep in magnitude vector
        for y in range(magnitude_db.shape[1]):
          y_test.append(label)

        #Add random period of silence in length of 10-100 samples
        for j in range(random.randint(sil_dur_min, sil_dur_max)):
          X_test = np.vstack((X_test, -80*np.ones((1,magnitude_db.shape[0])) ))
          y_test.append('None')

# Drop the first row in X_train and X_test
X_train = np.delete(X_train,0, axis=0)
X_test = np.delete(X_test,0, axis=0)

# %%
   np.savez_compressed(
    "generated_windows.npz",
    windows=X_train,
    labels=X_test
   #)
# Out:
# 160

# %%
# Set a length of plot window in samples
Plot_Window = 100

y_train_overhead = np.array((y_train))
#y_train_overhead = y_train_overhead =='overheads'

# Create subplots
fig, axs = plt.subplots(2, figsize=(12, 8))

# Plot the spectrogram on the first subplot
img = axs[0].imshow(X_val[0:1,:,:].T, aspect='auto', origin='lower', cmap='jet')

# Add colorbar to the plot
#plt.colorbar(img, ax=axs[0], label='Magnitude')

# Set labels and title for the first subplot
axs[0].set_xlabel('Samples')
axs[0].set_ylabel('Frequency Bin')
axs[0].set_title('STFT Spectrogram')
axs[0].set_xlim(0, Plot_Window)

axs[1].plot(y_pred[:Plot_Window])
axs[1].set_xlabel('Samples')
#axs[1].set_title('Drug labels')
axs[1].set_xlim(0, Plot_Window)
axs[1].grid(True)

# Show the plot
plt.show()

# %%
# Encode labels into one-hot vectors
encoder = OneHotEncoder(sparse_output=False)
y_train_OH = encoder.fit_transform(np.array(y_train).reshape(-1, 1))
#y_train_OH = y_train_overhead;


# Create input output tensors
X = X_train.reshape((-1,X_train.shape[0],X_train.shape[1]))
Y = y_train_OH.reshape((-1,y_train_OH.shape[0],y_train_OH.shape[1]))

# Print shape of Input/Output vector for training for check
print(X.shape)
print(Y.shape)

# Use the same encoder to transform the test data
y_test_OH = encoder.transform(np.array(y_test).reshape(-1, 1))

X_val = X_test.reshape((-1,X_test.shape[0],X_test.shape[1]))
Y_val = y_test_OH.reshape((-1,y_test_OH.shape[0],y_test_OH.shape[1]))

# Print shape of Input/Output vector for training for check
print(X_val.shape)
print(Y_val.shape)
# Out:
# (1, 2738, 1025)
# (1, 2738, 5)
# (1, 309, 1025)
# (1, 309, 5)

# %%
np.savez_compressed(
    "generated_windows.npz",
    X_train=X,
    Y_train=Y,
    X_val=X_val,
    Y_val=Y_val
   )

# %%
# Define the LSTM model
model_FF = Sequential()

model_FF.add(Dense(1025,activation='linear',input_shape=(None,X.shape[2])))
model_FF.add(Dense(512,activation='linear'))

model_FF.add(Dense(5,activation='softmax'))
model_FF.summary()

# Early stop is used to make sure model is not overfitting. If 'val_loss' is not improved within 10 epochs (patience=10), the training is automaticlly stopped.
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=1, mode='auto')

# Define the optimizer with a specific learning rate
optimizer = Adam(learning_rate=0.0005)  # Adjust the learning rate as needed
model_FF.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

model_FF.fit(X, Y,  validation_data=(X_val,Y_val), epochs=2500 )
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, None, 1025)     │     1,051,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, None, 512)      │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, None, 5)        │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,579,527 (6.03 MB)
#  Trainable params: 1,579,527 (6.03 MB)
#  Non-trainable params: 0 (0.00 B)
# Streaming output truncated to the last 5000 lines.
# Epoch 1/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1892 - loss: 82.8098 - val_accuracy: 0.2019 - val_loss: 107.9533
# Epoch 2/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.2078 - loss: 297.5905 - val_accuracy: 0.2051 - val_loss: 380.1439
# Epoch 3/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.2104 - loss: 665.7399 - val_accuracy: 0.3590 - val_loss: 843.6988
# Epoch 4/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step - accuracy: 0.1928 - loss: 1226.9810 - val_accuracy: 0.1795 - val_loss: 1460.7396
# Epoch 5/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.1585 - loss: 1727.3046 - val_accuracy: 0.1795 - val_loss: 1290.5934
# Epoch 6/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - accuracy: 0.1585 - loss: 1541.0618 - val_accuracy: 0.1795 - val_loss: 709.6889
# Epoch 7/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.1585 - loss: 1001.5372 - val_accuracy: 0.3590 - val_loss: 734.5724
# Epoch 8/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.1928 - loss: 1003.0387 - val_accuracy: 0.3590 - val_loss: 566.3694
# Epoch 9/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step - accuracy: 0.1928 - loss: 771.5365 - val_accuracy: 0.2051 - val_loss: 999.1323
# Epoch 10/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.2104 - loss: 1040.7208 - val_accuracy: 0.2051 - val_loss: 1049.4463
# Epoch 11/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - accuracy: 0.2104 - loss: 1008.6367 - val_accuracy: 0.2051 - val_loss: 797.0590
# Epoch 12/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - accuracy: 0.2104 - loss: 742.3735 - val_accuracy: 0.2051 - val_loss: 441.8717
# Epoch 13/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.2104 - loss: 421.5801 - val_accuracy: 0.2051 - val_loss: 458.5824
# Epoch 14/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step - accuracy: 0.2104 - loss: 424.7300 - val_accuracy: 0.2051 - val_loss: 267.4332
# Epoch 15/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - accuracy: 0.2107 - loss: 248.9057 - val_accuracy: 0.3910 - val_loss: 201.1220
# Epoch 16/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 0.4072 - loss: 198.5798 - val_accuracy: 0.0513 - val_loss: 343.1759
# Epoch 17/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step - accuracy: 0.2279 - loss: 315.4088 - val_accuracy: 0.2660 - val_loss: 225.0270
# Epoch 18/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.3404 - loss: 221.8640 - val_accuracy: 0.2692 - val_loss: 232.8440
# Epoch 19/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 805ms/step - accuracy: 0.3214 - loss: 218.4496 - val_accuracy: 0.3333 - val_loss: 212.3956
# Epoch 20/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step - accuracy: 0.2465 - loss: 221.2269 - val_accuracy: 0.3590 - val_loss: 188.6982
# Epoch 21/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 802ms/step - accuracy: 0.1928 - loss: 219.2558 - val_accuracy: 0.3846 - val_loss: 158.7288
# Epoch 22/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 788ms/step - accuracy: 0.3700 - loss: 187.9512 - val_accuracy: 0.2051 - val_loss: 209.4440
# Epoch 23/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step - accuracy: 0.2104 - loss: 231.4895 - val_accuracy: 0.5481 - val_loss: 126.3530
# Epoch 24/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step - accuracy: 0.3850 - loss: 168.9403 - val_accuracy: 0.3590 - val_loss: 136.9026
# Epoch 25/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1928 - loss: 185.1394 - val_accuracy: 0.3782 - val_loss: 103.1062
# Epoch 26/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.2761 - loss: 141.2720 - val_accuracy: 0.2404 - val_loss: 114.6222
# Epoch 27/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.1921 - loss: 131.1360 - val_accuracy: 0.4071 - val_loss: 40.5389
# Epoch 28/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.3459 - loss: 58.5742 - val_accuracy: 0.2051 - val_loss: 40.2197
# Epoch 29/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step - accuracy: 0.2115 - loss: 58.8334 - val_accuracy: 0.3558 - val_loss: 42.5432
# Epoch 30/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.4350 - loss: 49.8495 - val_accuracy: 0.6731 - val_loss: 54.4832
# Epoch 31/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - accuracy: 0.5581 - loss: 55.1300 - val_accuracy: 0.6090 - val_loss: 64.1682
# Epoch 32/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 0.6231 - loss: 57.3348 - val_accuracy: 0.6731 - val_loss: 52.4554
# Epoch 33/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.6717 - loss: 47.2148 - val_accuracy: 0.5641 - val_loss: 43.3659
# Epoch 34/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step - accuracy: 0.6220 - loss: 39.3175 - val_accuracy: 0.1218 - val_loss: 57.4270
# Epoch 35/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step - accuracy: 0.2940 - loss: 46.9579 - val_accuracy: 0.1410 - val_loss: 39.4024
# Epoch 36/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.2955 - loss: 29.9940 - val_accuracy: 0.3910 - val_loss: 25.2838
# Epoch 37/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.5814 - loss: 19.5911 - val_accuracy: 0.6795 - val_loss: 8.6905
# Epoch 38/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - accuracy: 0.7392 - loss: 6.9545 - val_accuracy: 0.6314 - val_loss: 15.9669
# Epoch 39/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.6286 - loss: 17.2720 - val_accuracy: 0.5673 - val_loss: 21.0041
# Epoch 40/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5712 - loss: 20.7421 - val_accuracy: 0.5385 - val_loss: 20.0175
# Epoch 41/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5924 - loss: 16.2810 - val_accuracy: 0.6218 - val_loss: 13.4953
# Epoch 42/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step - accuracy: 0.6486 - loss: 14.6629 - val_accuracy: 0.6987 - val_loss: 9.4783
# Epoch 43/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6768 - loss: 15.3199 - val_accuracy: 0.8462 - val_loss: 4.3427
# Epoch 44/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7210 - loss: 14.7879 - val_accuracy: 0.8077 - val_loss: 3.6792
# Epoch 45/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.6695 - loss: 18.3017 - val_accuracy: 0.6955 - val_loss: 4.9382
# Epoch 46/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - accuracy: 0.6308 - loss: 17.9544 - val_accuracy: 0.8429 - val_loss: 3.3203
# Epoch 47/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step - accuracy: 0.8009 - loss: 14.3592 - val_accuracy: 0.6154 - val_loss: 7.5328
# Epoch 48/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.6936 - loss: 12.6223 - val_accuracy: 0.8590 - val_loss: 2.4733
# Epoch 49/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8411 - loss: 7.3795 - val_accuracy: 0.9199 - val_loss: 1.1252
# Epoch 50/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step - accuracy: 0.8875 - loss: 3.8039 - val_accuracy: 0.9263 - val_loss: 0.7970
# Epoch 51/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step - accuracy: 0.9039 - loss: 1.9101 - val_accuracy: 0.8878 - val_loss: 1.6366
# Epoch 52/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.8678 - loss: 2.1777 - val_accuracy: 0.8622 - val_loss: 1.9435
# Epoch 53/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step - accuracy: 0.8524 - loss: 2.7701 - val_accuracy: 0.8846 - val_loss: 1.9063
# Epoch 54/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 0.8608 - loss: 3.1559 - val_accuracy: 0.8814 - val_loss: 2.7967
# Epoch 55/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - accuracy: 0.8638 - loss: 3.7706 - val_accuracy: 0.8077 - val_loss: 4.4470
# Epoch 56/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.8101 - loss: 4.4982 - val_accuracy: 0.6667 - val_loss: 7.0743
# Epoch 57/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step - accuracy: 0.7568 - loss: 4.9985 - val_accuracy: 0.6282 - val_loss: 8.1373
# Epoch 58/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 0.7768 - loss: 4.7622 - val_accuracy: 0.8013 - val_loss: 2.9728
# Epoch 59/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.8700 - loss: 2.2912 - val_accuracy: 0.8910 - val_loss: 1.5297
# Epoch 60/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - accuracy: 0.9109 - loss: 1.6137 - val_accuracy: 0.9231 - val_loss: 0.6089
# Epoch 61/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - accuracy: 0.9343 - loss: 1.2006 - val_accuracy: 0.9295 - val_loss: 0.5339
# Epoch 62/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step - accuracy: 0.9193 - loss: 1.1513 - val_accuracy: 0.8942 - val_loss: 0.9692
# Epoch 63/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 765ms/step - accuracy: 0.9054 - loss: 1.3363 - val_accuracy: 0.9103 - val_loss: 0.7755
# Epoch 64/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9182 - loss: 1.2695 - val_accuracy: 0.7532 - val_loss: 1.1175
# Epoch 65/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step - accuracy: 0.7816 - loss: 1.8064 - val_accuracy: 0.8333 - val_loss: 1.6990
# Epoch 66/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step - accuracy: 0.9080 - loss: 1.5410 - val_accuracy: 0.8109 - val_loss: 2.1444
# Epoch 67/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step - accuracy: 0.9028 - loss: 1.6009 - val_accuracy: 0.9006 - val_loss: 0.8529
# Epoch 68/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9430 - loss: 1.2097 - val_accuracy: 0.9071 - val_loss: 1.0826
# Epoch 69/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9350 - loss: 1.3981 - val_accuracy: 0.8974 - val_loss: 1.2363
# Epoch 70/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.9328 - loss: 1.3383 - val_accuracy: 0.8782 - val_loss: 1.2939
# Epoch 71/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9412 - loss: 1.1091 - val_accuracy: 0.8333 - val_loss: 2.0577
# Epoch 72/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9222 - loss: 1.3150 - val_accuracy: 0.8558 - val_loss: 1.9591
# Epoch 73/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9200 - loss: 1.3031 - val_accuracy: 0.9006 - val_loss: 1.4150
# Epoch 74/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step - accuracy: 0.9332 - loss: 1.2047 - val_accuracy: 0.9071 - val_loss: 1.3944
# Epoch 75/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.9262 - loss: 1.3399 - val_accuracy: 0.9103 - val_loss: 1.2646
# Epoch 76/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step - accuracy: 0.9222 - loss: 1.3403 - val_accuracy: 0.9167 - val_loss: 1.0502
# Epoch 77/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step - accuracy: 0.9284 - loss: 1.1741 - val_accuracy: 0.8974 - val_loss: 1.1119
# Epoch 78/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.9270 - loss: 1.0974 - val_accuracy: 0.8878 - val_loss: 1.1791
# Epoch 79/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step - accuracy: 0.9324 - loss: 0.9600 - val_accuracy: 0.8878 - val_loss: 1.1213
# Epoch 80/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - accuracy: 0.9408 - loss: 0.7691 - val_accuracy: 0.8846 - val_loss: 1.2772
# Epoch 81/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step - accuracy: 0.9430 - loss: 0.7348 - val_accuracy: 0.8750 - val_loss: 1.4259
# Epoch 82/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.9416 - loss: 0.7506 - val_accuracy: 0.8750 - val_loss: 1.5396
# Epoch 83/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9449 - loss: 0.6821 - val_accuracy: 0.8429 - val_loss: 1.6193
# Epoch 84/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.9416 - loss: 0.6671 - val_accuracy: 0.8782 - val_loss: 1.2521
# Epoch 85/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9500 - loss: 0.5997 - val_accuracy: 0.9006 - val_loss: 0.7946
# Epoch 86/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step - accuracy: 0.9529 - loss: 0.5578 - val_accuracy: 0.9167 - val_loss: 0.5423
# Epoch 87/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9525 - loss: 0.5864 - val_accuracy: 0.9231 - val_loss: 0.4644
# Epoch 88/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step - accuracy: 0.9507 - loss: 0.6059 - val_accuracy: 0.9199 - val_loss: 0.4783
# Epoch 89/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step - accuracy: 0.9503 - loss: 0.5975 - val_accuracy: 0.9135 - val_loss: 0.5983
# Epoch 90/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step - accuracy: 0.9500 - loss: 0.5741 - val_accuracy: 0.9038 - val_loss: 0.7330
# Epoch 91/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9525 - loss: 0.5382 - val_accuracy: 0.8942 - val_loss: 0.8771
# Epoch 92/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step - accuracy: 0.9547 - loss: 0.5236 - val_accuracy: 0.8846 - val_loss: 1.0456
# Epoch 93/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step - accuracy: 0.9529 - loss: 0.5351 - val_accuracy: 0.8782 - val_loss: 1.1649
# Epoch 94/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step - accuracy: 0.9514 - loss: 0.5406 - val_accuracy: 0.8814 - val_loss: 1.1792
# Epoch 95/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step - accuracy: 0.9522 - loss: 0.5287 - val_accuracy: 0.8814 - val_loss: 1.0757
# Epoch 96/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9514 - loss: 0.5037 - val_accuracy: 0.9006 - val_loss: 0.8977
# Epoch 97/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.9536 - loss: 0.4824 - val_accuracy: 0.9038 - val_loss: 0.7210
# Epoch 98/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step - accuracy: 0.9565 - loss: 0.4786 - val_accuracy: 0.9103 - val_loss: 0.6037
# Epoch 99/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step - accuracy: 0.9569 - loss: 0.4858 - val_accuracy: 0.9071 - val_loss: 0.5636
# Epoch 100/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.9562 - loss: 0.4875 - val_accuracy: 0.9103 - val_loss: 0.6012
# Epoch 101/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.9565 - loss: 0.4753 - val_accuracy: 0.9103 - val_loss: 0.7055
# Epoch 102/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 0.9584 - loss: 0.4583 - val_accuracy: 0.9071 - val_loss: 0.8490
# Epoch 103/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step - accuracy: 0.9562 - loss: 0.4505 - val_accuracy: 0.8942 - val_loss: 0.9823
# Epoch 104/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9533 - loss: 0.4608 - val_accuracy: 0.8910 - val_loss: 1.0367
# Epoch 105/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step - accuracy: 0.9529 - loss: 0.4492 - val_accuracy: 0.8942 - val_loss: 0.9852
# Epoch 106/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9551 - loss: 0.4399 - val_accuracy: 0.8974 - val_loss: 0.8632
# Epoch 107/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - accuracy: 0.9558 - loss: 0.4300 - val_accuracy: 0.9038 - val_loss: 0.7545
# Epoch 108/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 803ms/step - accuracy: 0.9562 - loss: 0.4258 - val_accuracy: 0.9135 - val_loss: 0.6989
# Epoch 109/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 813ms/step - accuracy: 0.9602 - loss: 0.4213 - val_accuracy: 0.9071 - val_loss: 0.6960
# Epoch 110/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 777ms/step - accuracy: 0.9598 - loss: 0.4184 - val_accuracy: 0.9103 - val_loss: 0.7114
# Epoch 111/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step - accuracy: 0.9598 - loss: 0.4137 - val_accuracy: 0.9071 - val_loss: 0.7228
# Epoch 112/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 721ms/step - accuracy: 0.9617 - loss: 0.4057 - val_accuracy: 0.9103 - val_loss: 0.7482
# Epoch 113/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9627 - loss: 0.4011 - val_accuracy: 0.9071 - val_loss: 0.7949
# Epoch 114/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - accuracy: 0.9602 - loss: 0.3983 - val_accuracy: 0.9071 - val_loss: 0.8442
# Epoch 115/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.9609 - loss: 0.3946 - val_accuracy: 0.9071 - val_loss: 0.8611
# Epoch 116/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 0.9617 - loss: 0.3907 - val_accuracy: 0.9071 - val_loss: 0.8249
# Epoch 117/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.9635 - loss: 0.3844 - val_accuracy: 0.9103 - val_loss: 0.7592
# Epoch 118/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.9631 - loss: 0.3787 - val_accuracy: 0.9167 - val_loss: 0.7104
# Epoch 119/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - accuracy: 0.9642 - loss: 0.3754 - val_accuracy: 0.9199 - val_loss: 0.7007
# Epoch 120/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9646 - loss: 0.3716 - val_accuracy: 0.9135 - val_loss: 0.7227
# Epoch 121/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - accuracy: 0.9627 - loss: 0.3678 - val_accuracy: 0.9135 - val_loss: 0.7494
# Epoch 122/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9624 - loss: 0.3633 - val_accuracy: 0.9103 - val_loss: 0.7671
# Epoch 123/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step - accuracy: 0.9635 - loss: 0.3584 - val_accuracy: 0.9038 - val_loss: 0.7851
# Epoch 124/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9635 - loss: 0.3551 - val_accuracy: 0.9038 - val_loss: 0.8068
# Epoch 125/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step - accuracy: 0.9635 - loss: 0.3516 - val_accuracy: 0.9071 - val_loss: 0.8213
# Epoch 126/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step - accuracy: 0.9649 - loss: 0.3476 - val_accuracy: 0.9135 - val_loss: 0.8124
# Epoch 127/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step - accuracy: 0.9649 - loss: 0.3436 - val_accuracy: 0.9135 - val_loss: 0.7766
# Epoch 128/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step - accuracy: 0.9660 - loss: 0.3392 - val_accuracy: 0.9167 - val_loss: 0.7340
# Epoch 129/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.9668 - loss: 0.3357 - val_accuracy: 0.9167 - val_loss: 0.7110
# Epoch 130/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step - accuracy: 0.9679 - loss: 0.3325 - val_accuracy: 0.9167 - val_loss: 0.7155
# Epoch 131/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 905ms/step - accuracy: 0.9675 - loss: 0.3289 - val_accuracy: 0.9167 - val_loss: 0.7334
# Epoch 132/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9671 - loss: 0.3254 - val_accuracy: 0.9167 - val_loss: 0.7466
# Epoch 133/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step - accuracy: 0.9675 - loss: 0.3217 - val_accuracy: 0.9167 - val_loss: 0.7537
# Epoch 134/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 821ms/step - accuracy: 0.9675 - loss: 0.3183 - val_accuracy: 0.9167 - val_loss: 0.7624
# Epoch 135/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9679 - loss: 0.3152 - val_accuracy: 0.9167 - val_loss: 0.7730
# Epoch 136/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9682 - loss: 0.3119 - val_accuracy: 0.9167 - val_loss: 0.7767
# Epoch 137/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.9682 - loss: 0.3086 - val_accuracy: 0.9167 - val_loss: 0.7653
# Epoch 138/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.9682 - loss: 0.3053 - val_accuracy: 0.9167 - val_loss: 0.7432
# Epoch 139/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 0.9682 - loss: 0.3021 - val_accuracy: 0.9167 - val_loss: 0.7258
# Epoch 140/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step - accuracy: 0.9693 - loss: 0.2992 - val_accuracy: 0.9167 - val_loss: 0.7243
# Epoch 141/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - accuracy: 0.9697 - loss: 0.2962 - val_accuracy: 0.9167 - val_loss: 0.7356
# Epoch 142/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - accuracy: 0.9686 - loss: 0.2931 - val_accuracy: 0.9167 - val_loss: 0.7476
# Epoch 143/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9690 - loss: 0.2902 - val_accuracy: 0.9167 - val_loss: 0.7536
# Epoch 144/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - accuracy: 0.9697 - loss: 0.2872 - val_accuracy: 0.9167 - val_loss: 0.7562
# Epoch 145/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - accuracy: 0.9704 - loss: 0.2844 - val_accuracy: 0.9167 - val_loss: 0.7596
# Epoch 146/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step - accuracy: 0.9704 - loss: 0.2815 - val_accuracy: 0.9167 - val_loss: 0.7619
# Epoch 147/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.9697 - loss: 0.2787 - val_accuracy: 0.9167 - val_loss: 0.7580
# Epoch 148/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - accuracy: 0.9701 - loss: 0.2758 - val_accuracy: 0.9167 - val_loss: 0.7459
# Epoch 149/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 0.9711 - loss: 0.2730 - val_accuracy: 0.9167 - val_loss: 0.7323
# Epoch 150/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step - accuracy: 0.9719 - loss: 0.2703 - val_accuracy: 0.9167 - val_loss: 0.7262
# Epoch 151/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step - accuracy: 0.9722 - loss: 0.2677 - val_accuracy: 0.9167 - val_loss: 0.7301
# Epoch 152/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step - accuracy: 0.9722 - loss: 0.2649 - val_accuracy: 0.9167 - val_loss: 0.7383
# Epoch 153/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9715 - loss: 0.2623 - val_accuracy: 0.9167 - val_loss: 0.7438
# Epoch 154/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 765ms/step - accuracy: 0.9719 - loss: 0.2596 - val_accuracy: 0.9167 - val_loss: 0.7455
# Epoch 155/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step - accuracy: 0.9715 - loss: 0.2570 - val_accuracy: 0.9167 - val_loss: 0.7467
# Epoch 156/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9715 - loss: 0.2544 - val_accuracy: 0.9167 - val_loss: 0.7486
# Epoch 157/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step - accuracy: 0.9715 - loss: 0.2518 - val_accuracy: 0.9167 - val_loss: 0.7485
# Epoch 158/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9719 - loss: 0.2492 - val_accuracy: 0.9167 - val_loss: 0.7437
# Epoch 159/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - accuracy: 0.9715 - loss: 0.2466 - val_accuracy: 0.9167 - val_loss: 0.7360
# Epoch 160/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - accuracy: 0.9719 - loss: 0.2441 - val_accuracy: 0.9167 - val_loss: 0.7310
# Epoch 161/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step - accuracy: 0.9719 - loss: 0.2416 - val_accuracy: 0.9167 - val_loss: 0.7321
# Epoch 162/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - accuracy: 0.9719 - loss: 0.2391 - val_accuracy: 0.9167 - val_loss: 0.7371
# Epoch 163/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step - accuracy: 0.9715 - loss: 0.2366 - val_accuracy: 0.9167 - val_loss: 0.7412
# Epoch 164/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.9715 - loss: 0.2341 - val_accuracy: 0.9167 - val_loss: 0.7423
# Epoch 165/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step - accuracy: 0.9715 - loss: 0.2316 - val_accuracy: 0.9167 - val_loss: 0.7421
# Epoch 166/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9719 - loss: 0.2292 - val_accuracy: 0.9167 - val_loss: 0.7424
# Epoch 167/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.9719 - loss: 0.2268 - val_accuracy: 0.9167 - val_loss: 0.7421
# Epoch 168/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.9719 - loss: 0.2244 - val_accuracy: 0.9167 - val_loss: 0.7394
# Epoch 169/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.9722 - loss: 0.2220 - val_accuracy: 0.9167 - val_loss: 0.7345
# Epoch 170/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 0.9733 - loss: 0.2196 - val_accuracy: 0.9167 - val_loss: 0.7309
# Epoch 171/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step - accuracy: 0.9733 - loss: 0.2173 - val_accuracy: 0.9167 - val_loss: 0.7311
# Epoch 172/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.9733 - loss: 0.2149 - val_accuracy: 0.9167 - val_loss: 0.7342
# Epoch 173/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step - accuracy: 0.9733 - loss: 0.2126 - val_accuracy: 0.9167 - val_loss: 0.7367
# Epoch 174/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step - accuracy: 0.9741 - loss: 0.2103 - val_accuracy: 0.9167 - val_loss: 0.7372
# Epoch 175/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 844ms/step - accuracy: 0.9741 - loss: 0.2080 - val_accuracy: 0.9167 - val_loss: 0.7369
# Epoch 176/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step - accuracy: 0.9741 - loss: 0.2057 - val_accuracy: 0.9167 - val_loss: 0.7371
# Epoch 177/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9741 - loss: 0.2034 - val_accuracy: 0.9167 - val_loss: 0.7370
# Epoch 178/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step - accuracy: 0.9741 - loss: 0.2011 - val_accuracy: 0.9167 - val_loss: 0.7352
# Epoch 179/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step - accuracy: 0.9741 - loss: 0.1989 - val_accuracy: 0.9167 - val_loss: 0.7322
# Epoch 180/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step - accuracy: 0.9741 - loss: 0.1966 - val_accuracy: 0.9167 - val_loss: 0.7304
# Epoch 181/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.9741 - loss: 0.1944 - val_accuracy: 0.9167 - val_loss: 0.7310
# Epoch 182/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.9744 - loss: 0.1922 - val_accuracy: 0.9167 - val_loss: 0.7329
# Epoch 183/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.9748 - loss: 0.1900 - val_accuracy: 0.9167 - val_loss: 0.7341
# Epoch 184/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.9744 - loss: 0.1878 - val_accuracy: 0.9167 - val_loss: 0.7340
# Epoch 185/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - accuracy: 0.9748 - loss: 0.1857 - val_accuracy: 0.9167 - val_loss: 0.7337
# Epoch 186/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - accuracy: 0.9752 - loss: 0.1835 - val_accuracy: 0.9167 - val_loss: 0.7338
# Epoch 187/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 0.9755 - loss: 0.1814 - val_accuracy: 0.9167 - val_loss: 0.7333
# Epoch 188/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - accuracy: 0.9759 - loss: 0.1793 - val_accuracy: 0.9167 - val_loss: 0.7316
# Epoch 189/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step - accuracy: 0.9759 - loss: 0.1772 - val_accuracy: 0.9167 - val_loss: 0.7296
# Epoch 190/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.9763 - loss: 0.1751 - val_accuracy: 0.9167 - val_loss: 0.7289
# Epoch 191/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - accuracy: 0.9766 - loss: 0.1730 - val_accuracy: 0.9167 - val_loss: 0.7296
# Epoch 192/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9766 - loss: 0.1710 - val_accuracy: 0.9167 - val_loss: 0.7303
# Epoch 193/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9766 - loss: 0.1690 - val_accuracy: 0.9167 - val_loss: 0.7301
# Epoch 194/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step - accuracy: 0.9766 - loss: 0.1669 - val_accuracy: 0.9167 - val_loss: 0.7296
# Epoch 195/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9770 - loss: 0.1650 - val_accuracy: 0.9167 - val_loss: 0.7294
# Epoch 196/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9770 - loss: 0.1630 - val_accuracy: 0.9167 - val_loss: 0.7291
# Epoch 197/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 717ms/step - accuracy: 0.9770 - loss: 0.1611 - val_accuracy: 0.9167 - val_loss: 0.7280
# Epoch 198/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9777 - loss: 0.1591 - val_accuracy: 0.9167 - val_loss: 0.7265
# Epoch 199/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step - accuracy: 0.9777 - loss: 0.1572 - val_accuracy: 0.9167 - val_loss: 0.7256
# Epoch 200/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9781 - loss: 0.1554 - val_accuracy: 0.9167 - val_loss: 0.7257
# Epoch 201/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9785 - loss: 0.1535 - val_accuracy: 0.9167 - val_loss: 0.7261
# Epoch 202/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step - accuracy: 0.9785 - loss: 0.1517 - val_accuracy: 0.9167 - val_loss: 0.7259
# Epoch 203/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step - accuracy: 0.9788 - loss: 0.1499 - val_accuracy: 0.9167 - val_loss: 0.7254
# Epoch 204/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step - accuracy: 0.9788 - loss: 0.1481 - val_accuracy: 0.9167 - val_loss: 0.7250
# Epoch 205/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.9792 - loss: 0.1463 - val_accuracy: 0.9167 - val_loss: 0.7246
# Epoch 206/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step - accuracy: 0.9792 - loss: 0.1446 - val_accuracy: 0.9199 - val_loss: 0.7237
# Epoch 207/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step - accuracy: 0.9792 - loss: 0.1429 - val_accuracy: 0.9199 - val_loss: 0.7225
# Epoch 208/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step - accuracy: 0.9795 - loss: 0.1412 - val_accuracy: 0.9199 - val_loss: 0.7217
# Epoch 209/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9795 - loss: 0.1395 - val_accuracy: 0.9199 - val_loss: 0.7216
# Epoch 210/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9795 - loss: 0.1378 - val_accuracy: 0.9199 - val_loss: 0.7215
# Epoch 211/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.9795 - loss: 0.1362 - val_accuracy: 0.9199 - val_loss: 0.7210
# Epoch 212/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9795 - loss: 0.1346 - val_accuracy: 0.9199 - val_loss: 0.7204
# Epoch 213/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step - accuracy: 0.9795 - loss: 0.1330 - val_accuracy: 0.9199 - val_loss: 0.7199
# Epoch 214/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9799 - loss: 0.1314 - val_accuracy: 0.9199 - val_loss: 0.7194
# Epoch 215/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.9799 - loss: 0.1299 - val_accuracy: 0.9199 - val_loss: 0.7185
# Epoch 216/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 819ms/step - accuracy: 0.9799 - loss: 0.1283 - val_accuracy: 0.9231 - val_loss: 0.7175
# Epoch 217/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step - accuracy: 0.9803 - loss: 0.1268 - val_accuracy: 0.9231 - val_loss: 0.7169
# Epoch 218/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 886ms/step - accuracy: 0.9803 - loss: 0.1253 - val_accuracy: 0.9231 - val_loss: 0.7167
# Epoch 219/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step - accuracy: 0.9803 - loss: 0.1238 - val_accuracy: 0.9231 - val_loss: 0.7164
# Epoch 220/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 887ms/step - accuracy: 0.9803 - loss: 0.1223 - val_accuracy: 0.9231 - val_loss: 0.7159
# Epoch 221/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 855ms/step - accuracy: 0.9803 - loss: 0.1209 - val_accuracy: 0.9231 - val_loss: 0.7153
# Epoch 222/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.9803 - loss: 0.1194 - val_accuracy: 0.9231 - val_loss: 0.7148
# Epoch 223/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - accuracy: 0.9803 - loss: 0.1180 - val_accuracy: 0.9231 - val_loss: 0.7142
# Epoch 224/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9806 - loss: 0.1165 - val_accuracy: 0.9231 - val_loss: 0.7133
# Epoch 225/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step - accuracy: 0.9810 - loss: 0.1151 - val_accuracy: 0.9231 - val_loss: 0.7125
# Epoch 226/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9810 - loss: 0.1137 - val_accuracy: 0.9231 - val_loss: 0.7120
# Epoch 227/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step - accuracy: 0.9810 - loss: 0.1124 - val_accuracy: 0.9231 - val_loss: 0.7115
# Epoch 228/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9810 - loss: 0.1110 - val_accuracy: 0.9231 - val_loss: 0.7110
# Epoch 229/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step - accuracy: 0.9814 - loss: 0.1097 - val_accuracy: 0.9231 - val_loss: 0.7103
# Epoch 230/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9814 - loss: 0.1083 - val_accuracy: 0.9231 - val_loss: 0.7097
# Epoch 231/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step - accuracy: 0.9814 - loss: 0.1070 - val_accuracy: 0.9231 - val_loss: 0.7091
# Epoch 232/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - accuracy: 0.9817 - loss: 0.1057 - val_accuracy: 0.9231 - val_loss: 0.7083
# Epoch 233/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - accuracy: 0.9817 - loss: 0.1044 - val_accuracy: 0.9231 - val_loss: 0.7075
# Epoch 234/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - accuracy: 0.9817 - loss: 0.1032 - val_accuracy: 0.9231 - val_loss: 0.7069
# Epoch 235/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.9817 - loss: 0.1019 - val_accuracy: 0.9231 - val_loss: 0.7065
# Epoch 236/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step - accuracy: 0.9821 - loss: 0.1007 - val_accuracy: 0.9231 - val_loss: 0.7060
# Epoch 237/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9825 - loss: 0.0995 - val_accuracy: 0.9231 - val_loss: 0.7054
# Epoch 238/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step - accuracy: 0.9828 - loss: 0.0983 - val_accuracy: 0.9231 - val_loss: 0.7049
# Epoch 239/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step - accuracy: 0.9828 - loss: 0.0971 - val_accuracy: 0.9231 - val_loss: 0.7044
# Epoch 240/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step - accuracy: 0.9832 - loss: 0.0960 - val_accuracy: 0.9231 - val_loss: 0.7037
# Epoch 241/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step - accuracy: 0.9832 - loss: 0.0949 - val_accuracy: 0.9231 - val_loss: 0.7030
# Epoch 242/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step - accuracy: 0.9836 - loss: 0.0937 - val_accuracy: 0.9231 - val_loss: 0.7023
# Epoch 243/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9836 - loss: 0.0927 - val_accuracy: 0.9231 - val_loss: 0.7018
# Epoch 244/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.9836 - loss: 0.0916 - val_accuracy: 0.9231 - val_loss: 0.7012
# Epoch 245/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.9839 - loss: 0.0905 - val_accuracy: 0.9231 - val_loss: 0.7006
# Epoch 246/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - accuracy: 0.9843 - loss: 0.0895 - val_accuracy: 0.9231 - val_loss: 0.6999
# Epoch 247/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - accuracy: 0.9850 - loss: 0.0884 - val_accuracy: 0.9231 - val_loss: 0.6993
# Epoch 248/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9850 - loss: 0.0874 - val_accuracy: 0.9231 - val_loss: 0.6987
# Epoch 249/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - accuracy: 0.9850 - loss: 0.0864 - val_accuracy: 0.9231 - val_loss: 0.6980
# Epoch 250/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step - accuracy: 0.9850 - loss: 0.0854 - val_accuracy: 0.9231 - val_loss: 0.6974
# Epoch 251/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 0.9850 - loss: 0.0845 - val_accuracy: 0.9231 - val_loss: 0.6969
# Epoch 252/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - accuracy: 0.9850 - loss: 0.0835 - val_accuracy: 0.9231 - val_loss: 0.6964
# Epoch 253/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.9854 - loss: 0.0826 - val_accuracy: 0.9231 - val_loss: 0.6958
# Epoch 254/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step - accuracy: 0.9858 - loss: 0.0816 - val_accuracy: 0.9231 - val_loss: 0.6952
# Epoch 255/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.9858 - loss: 0.0807 - val_accuracy: 0.9231 - val_loss: 0.6946
# Epoch 256/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.9861 - loss: 0.0798 - val_accuracy: 0.9231 - val_loss: 0.6940
# Epoch 257/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step - accuracy: 0.9872 - loss: 0.0789 - val_accuracy: 0.9231 - val_loss: 0.6934
# Epoch 258/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step - accuracy: 0.9876 - loss: 0.0780 - val_accuracy: 0.9231 - val_loss: 0.6927
# Epoch 259/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - accuracy: 0.9876 - loss: 0.0772 - val_accuracy: 0.9231 - val_loss: 0.6922
# Epoch 260/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step - accuracy: 0.9876 - loss: 0.0763 - val_accuracy: 0.9231 - val_loss: 0.6916
# Epoch 261/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step - accuracy: 0.9876 - loss: 0.0754 - val_accuracy: 0.9231 - val_loss: 0.6910
# Epoch 262/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 807ms/step - accuracy: 0.9876 - loss: 0.0746 - val_accuracy: 0.9231 - val_loss: 0.6904
# Epoch 263/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9879 - loss: 0.0738 - val_accuracy: 0.9231 - val_loss: 0.6899
# Epoch 264/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 789ms/step - accuracy: 0.9883 - loss: 0.0729 - val_accuracy: 0.9231 - val_loss: 0.6893
# Epoch 265/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 724ms/step - accuracy: 0.9883 - loss: 0.0721 - val_accuracy: 0.9231 - val_loss: 0.6887
# Epoch 266/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9883 - loss: 0.0713 - val_accuracy: 0.9231 - val_loss: 0.6882
# Epoch 267/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step - accuracy: 0.9883 - loss: 0.0705 - val_accuracy: 0.9231 - val_loss: 0.6876
# Epoch 268/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step - accuracy: 0.9883 - loss: 0.0697 - val_accuracy: 0.9231 - val_loss: 0.6871
# Epoch 269/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - accuracy: 0.9887 - loss: 0.0689 - val_accuracy: 0.9231 - val_loss: 0.6866
# Epoch 270/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step - accuracy: 0.9887 - loss: 0.0681 - val_accuracy: 0.9231 - val_loss: 0.6861
# Epoch 271/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step - accuracy: 0.9890 - loss: 0.0673 - val_accuracy: 0.9231 - val_loss: 0.6856
# Epoch 272/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step - accuracy: 0.9890 - loss: 0.0666 - val_accuracy: 0.9231 - val_loss: 0.6851
# Epoch 273/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step - accuracy: 0.9894 - loss: 0.0658 - val_accuracy: 0.9231 - val_loss: 0.6845
# Epoch 274/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.9894 - loss: 0.0650 - val_accuracy: 0.9231 - val_loss: 0.6840
# Epoch 275/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.9894 - loss: 0.0643 - val_accuracy: 0.9231 - val_loss: 0.6835
# Epoch 276/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9894 - loss: 0.0636 - val_accuracy: 0.9231 - val_loss: 0.6830
# Epoch 277/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step - accuracy: 0.9894 - loss: 0.0628 - val_accuracy: 0.9231 - val_loss: 0.6825
# Epoch 278/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step - accuracy: 0.9894 - loss: 0.0621 - val_accuracy: 0.9231 - val_loss: 0.6820
# Epoch 279/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step - accuracy: 0.9894 - loss: 0.0614 - val_accuracy: 0.9231 - val_loss: 0.6815
# Epoch 280/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - accuracy: 0.9898 - loss: 0.0607 - val_accuracy: 0.9231 - val_loss: 0.6810
# Epoch 281/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - accuracy: 0.9898 - loss: 0.0600 - val_accuracy: 0.9231 - val_loss: 0.6805
# Epoch 282/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - accuracy: 0.9898 - loss: 0.0593 - val_accuracy: 0.9231 - val_loss: 0.6800
# Epoch 283/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step - accuracy: 0.9898 - loss: 0.0586 - val_accuracy: 0.9231 - val_loss: 0.6795
# Epoch 284/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9898 - loss: 0.0579 - val_accuracy: 0.9231 - val_loss: 0.6791
# Epoch 285/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9898 - loss: 0.0572 - val_accuracy: 0.9263 - val_loss: 0.6786
# Epoch 286/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 874ms/step - accuracy: 0.9901 - loss: 0.0566 - val_accuracy: 0.9263 - val_loss: 0.6781
# Epoch 287/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 903ms/step - accuracy: 0.9901 - loss: 0.0559 - val_accuracy: 0.9263 - val_loss: 0.6776
# Epoch 288/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.9901 - loss: 0.0552 - val_accuracy: 0.9263 - val_loss: 0.6772
# Epoch 289/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - accuracy: 0.9901 - loss: 0.0546 - val_accuracy: 0.9263 - val_loss: 0.6767
# Epoch 290/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9901 - loss: 0.0539 - val_accuracy: 0.9263 - val_loss: 0.6763
# Epoch 291/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.9905 - loss: 0.0533 - val_accuracy: 0.9263 - val_loss: 0.6758
# Epoch 292/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.9909 - loss: 0.0527 - val_accuracy: 0.9263 - val_loss: 0.6754
# Epoch 293/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step - accuracy: 0.9912 - loss: 0.0520 - val_accuracy: 0.9263 - val_loss: 0.6750
# Epoch 294/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - accuracy: 0.9912 - loss: 0.0514 - val_accuracy: 0.9263 - val_loss: 0.6746
# Epoch 295/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - accuracy: 0.9912 - loss: 0.0508 - val_accuracy: 0.9263 - val_loss: 0.6742
# Epoch 296/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.9912 - loss: 0.0502 - val_accuracy: 0.9263 - val_loss: 0.6739
# Epoch 297/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step - accuracy: 0.9912 - loss: 0.0496 - val_accuracy: 0.9263 - val_loss: 0.6735
# Epoch 298/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.9912 - loss: 0.0491 - val_accuracy: 0.9263 - val_loss: 0.6731
# Epoch 299/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step - accuracy: 0.9912 - loss: 0.0485 - val_accuracy: 0.9263 - val_loss: 0.6728
# Epoch 300/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9912 - loss: 0.0479 - val_accuracy: 0.9263 - val_loss: 0.6724
# Epoch 301/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - accuracy: 0.9912 - loss: 0.0474 - val_accuracy: 0.9263 - val_loss: 0.6721
# Epoch 302/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step - accuracy: 0.9912 - loss: 0.0468 - val_accuracy: 0.9263 - val_loss: 0.6717
# Epoch 303/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step - accuracy: 0.9920 - loss: 0.0463 - val_accuracy: 0.9263 - val_loss: 0.6714
# Epoch 304/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 924ms/step - accuracy: 0.9920 - loss: 0.0458 - val_accuracy: 0.9263 - val_loss: 0.6710
# Epoch 305/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 800ms/step - accuracy: 0.9920 - loss: 0.0452 - val_accuracy: 0.9263 - val_loss: 0.6707
# Epoch 306/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 813ms/step - accuracy: 0.9923 - loss: 0.0447 - val_accuracy: 0.9263 - val_loss: 0.6703
# Epoch 307/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step - accuracy: 0.9920 - loss: 0.0442 - val_accuracy: 0.9263 - val_loss: 0.6700
# Epoch 308/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9920 - loss: 0.0437 - val_accuracy: 0.9263 - val_loss: 0.6697
# Epoch 309/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.9920 - loss: 0.0432 - val_accuracy: 0.9263 - val_loss: 0.6693
# Epoch 310/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - accuracy: 0.9920 - loss: 0.0428 - val_accuracy: 0.9263 - val_loss: 0.6690
# Epoch 311/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9920 - loss: 0.0423 - val_accuracy: 0.9263 - val_loss: 0.6687
# Epoch 312/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step - accuracy: 0.9920 - loss: 0.0418 - val_accuracy: 0.9263 - val_loss: 0.6684
# Epoch 313/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step - accuracy: 0.9923 - loss: 0.0414 - val_accuracy: 0.9263 - val_loss: 0.6681
# Epoch 314/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step - accuracy: 0.9923 - loss: 0.0409 - val_accuracy: 0.9263 - val_loss: 0.6677
# Epoch 315/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - accuracy: 0.9923 - loss: 0.0405 - val_accuracy: 0.9263 - val_loss: 0.6674
# Epoch 316/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step - accuracy: 0.9923 - loss: 0.0400 - val_accuracy: 0.9263 - val_loss: 0.6671
# Epoch 317/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step - accuracy: 0.9923 - loss: 0.0396 - val_accuracy: 0.9263 - val_loss: 0.6668
# Epoch 318/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - accuracy: 0.9923 - loss: 0.0391 - val_accuracy: 0.9263 - val_loss: 0.6665
# Epoch 319/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step - accuracy: 0.9923 - loss: 0.0387 - val_accuracy: 0.9263 - val_loss: 0.6662
# Epoch 320/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - accuracy: 0.9923 - loss: 0.0383 - val_accuracy: 0.9263 - val_loss: 0.6660
# Epoch 321/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step - accuracy: 0.9923 - loss: 0.0379 - val_accuracy: 0.9263 - val_loss: 0.6657
# Epoch 322/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.9927 - loss: 0.0375 - val_accuracy: 0.9263 - val_loss: 0.6654
# Epoch 323/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9927 - loss: 0.0370 - val_accuracy: 0.9263 - val_loss: 0.6651
# Epoch 324/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 0.9931 - loss: 0.0366 - val_accuracy: 0.9263 - val_loss: 0.6648
# Epoch 325/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step - accuracy: 0.9931 - loss: 0.0362 - val_accuracy: 0.9263 - val_loss: 0.6646
# Epoch 326/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step - accuracy: 0.9934 - loss: 0.0358 - val_accuracy: 0.9263 - val_loss: 0.6643
# Epoch 327/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step - accuracy: 0.9934 - loss: 0.0355 - val_accuracy: 0.9263 - val_loss: 0.6640
# Epoch 328/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9934 - loss: 0.0351 - val_accuracy: 0.9263 - val_loss: 0.6638
# Epoch 329/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step - accuracy: 0.9934 - loss: 0.0347 - val_accuracy: 0.9263 - val_loss: 0.6635
# Epoch 330/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step - accuracy: 0.9934 - loss: 0.0343 - val_accuracy: 0.9263 - val_loss: 0.6633
# Epoch 331/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9934 - loss: 0.0339 - val_accuracy: 0.9263 - val_loss: 0.6630
# Epoch 332/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.9938 - loss: 0.0335 - val_accuracy: 0.9263 - val_loss: 0.6628
# Epoch 333/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.9938 - loss: 0.0332 - val_accuracy: 0.9263 - val_loss: 0.6625
# Epoch 334/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9938 - loss: 0.0328 - val_accuracy: 0.9263 - val_loss: 0.6623
# Epoch 335/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.9938 - loss: 0.0324 - val_accuracy: 0.9263 - val_loss: 0.6620
# Epoch 336/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step - accuracy: 0.9938 - loss: 0.0321 - val_accuracy: 0.9263 - val_loss: 0.6618
# Epoch 337/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - accuracy: 0.9938 - loss: 0.0317 - val_accuracy: 0.9263 - val_loss: 0.6615
# Epoch 338/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - accuracy: 0.9942 - loss: 0.0314 - val_accuracy: 0.9263 - val_loss: 0.6613
# Epoch 339/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.9942 - loss: 0.0310 - val_accuracy: 0.9263 - val_loss: 0.6610
# Epoch 340/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step - accuracy: 0.9942 - loss: 0.0307 - val_accuracy: 0.9263 - val_loss: 0.6608
# Epoch 341/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.9942 - loss: 0.0303 - val_accuracy: 0.9263 - val_loss: 0.6605
# Epoch 342/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step - accuracy: 0.9942 - loss: 0.0300 - val_accuracy: 0.9263 - val_loss: 0.6603
# Epoch 343/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9942 - loss: 0.0297 - val_accuracy: 0.9263 - val_loss: 0.6600
# Epoch 344/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step - accuracy: 0.9942 - loss: 0.0293 - val_accuracy: 0.9263 - val_loss: 0.6598
# Epoch 345/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step - accuracy: 0.9942 - loss: 0.0290 - val_accuracy: 0.9263 - val_loss: 0.6595
# Epoch 346/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step - accuracy: 0.9942 - loss: 0.0287 - val_accuracy: 0.9263 - val_loss: 0.6593
# Epoch 347/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - accuracy: 0.9942 - loss: 0.0283 - val_accuracy: 0.9263 - val_loss: 0.6590
# Epoch 348/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - accuracy: 0.9942 - loss: 0.0280 - val_accuracy: 0.9263 - val_loss: 0.6588
# Epoch 349/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step - accuracy: 0.9942 - loss: 0.0277 - val_accuracy: 0.9263 - val_loss: 0.6586
# Epoch 350/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 853ms/step - accuracy: 0.9942 - loss: 0.0274 - val_accuracy: 0.9263 - val_loss: 0.6583
# Epoch 351/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 778ms/step - accuracy: 0.9942 - loss: 0.0271 - val_accuracy: 0.9263 - val_loss: 0.6581
# Epoch 352/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9945 - loss: 0.0267 - val_accuracy: 0.9263 - val_loss: 0.6578
# Epoch 353/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step - accuracy: 0.9945 - loss: 0.0264 - val_accuracy: 0.9263 - val_loss: 0.6576
# Epoch 354/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9945 - loss: 0.0261 - val_accuracy: 0.9263 - val_loss: 0.6573
# Epoch 355/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.9945 - loss: 0.0258 - val_accuracy: 0.9263 - val_loss: 0.6571
# Epoch 356/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - accuracy: 0.9945 - loss: 0.0255 - val_accuracy: 0.9263 - val_loss: 0.6569
# Epoch 357/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step - accuracy: 0.9945 - loss: 0.0252 - val_accuracy: 0.9263 - val_loss: 0.6566
# Epoch 358/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step - accuracy: 0.9945 - loss: 0.0249 - val_accuracy: 0.9263 - val_loss: 0.6564
# Epoch 359/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9945 - loss: 0.0246 - val_accuracy: 0.9263 - val_loss: 0.6562
# Epoch 360/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9945 - loss: 0.0244 - val_accuracy: 0.9263 - val_loss: 0.6560
# Epoch 361/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9945 - loss: 0.0241 - val_accuracy: 0.9263 - val_loss: 0.6558
# Epoch 362/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - accuracy: 0.9949 - loss: 0.0238 - val_accuracy: 0.9263 - val_loss: 0.6555
# Epoch 363/2500
# ...
# Epoch 2383/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - accuracy: 1.0000 - loss: 1.2126e-04 - val_accuracy: 0.9263 - val_loss: 0.5043
# Epoch 2384/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - accuracy: 1.0000 - loss: 1.2116e-04 - val_accuracy: 0.9263 - val_loss: 0.5043
# Epoch 2385/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 1.0000 - loss: 1.2107e-04 - val_accuracy: 0.9263 - val_loss: 0.5042
# Epoch 2386/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step - accuracy: 1.0000 - loss: 1.2097e-04 - val_accuracy: 0.9263 - val_loss: 0.5042
# Epoch 2387/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step - accuracy: 1.0000 - loss: 1.2088e-04 - val_accuracy: 0.9263 - val_loss: 0.5042
# Epoch 2388/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 788ms/step - accuracy: 1.0000 - loss: 1.2078e-04 - val_accuracy: 0.9263 - val_loss: 0.5041
# Epoch 2389/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 905ms/step - accuracy: 1.0000 - loss: 1.2069e-04 - val_accuracy: 0.9263 - val_loss: 0.5041
# Epoch 2390/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step - accuracy: 1.0000 - loss: 1.2059e-04 - val_accuracy: 0.9263 - val_loss: 0.5041
# Epoch 2391/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 861ms/step - accuracy: 1.0000 - loss: 1.2050e-04 - val_accuracy: 0.9263 - val_loss: 0.5041
# Epoch 2392/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 808ms/step - accuracy: 1.0000 - loss: 1.2040e-04 - val_accuracy: 0.9263 - val_loss: 0.5040
# Epoch 2393/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 770ms/step - accuracy: 1.0000 - loss: 1.2031e-04 - val_accuracy: 0.9263 - val_loss: 0.5040
# Epoch 2394/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - accuracy: 1.0000 - loss: 1.2021e-04 - val_accuracy: 0.9263 - val_loss: 0.5040
# Epoch 2395/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 1.0000 - loss: 1.2012e-04 - val_accuracy: 0.9263 - val_loss: 0.5040
# Epoch 2396/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step - accuracy: 1.0000 - loss: 1.2003e-04 - val_accuracy: 0.9263 - val_loss: 0.5039
# Epoch 2397/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - accuracy: 1.0000 - loss: 1.1993e-04 - val_accuracy: 0.9263 - val_loss: 0.5039
# Epoch 2398/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step - accuracy: 1.0000 - loss: 1.1984e-04 - val_accuracy: 0.9263 - val_loss: 0.5039
# Epoch 2399/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - accuracy: 1.0000 - loss: 1.1974e-04 - val_accuracy: 0.9263 - val_loss: 0.5039
# Epoch 2400/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step - accuracy: 1.0000 - loss: 1.1965e-04 - val_accuracy: 0.9263 - val_loss: 0.5038
# Epoch 2401/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - accuracy: 1.0000 - loss: 1.1956e-04 - val_accuracy: 0.9263 - val_loss: 0.5038
# Epoch 2402/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - accuracy: 1.0000 - loss: 1.1946e-04 - val_accuracy: 0.9263 - val_loss: 0.5038
# Epoch 2403/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - accuracy: 1.0000 - loss: 1.1937e-04 - val_accuracy: 0.9263 - val_loss: 0.5037
# Epoch 2404/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step - accuracy: 1.0000 - loss: 1.1928e-04 - val_accuracy: 0.9263 - val_loss: 0.5037
# Epoch 2405/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - accuracy: 1.0000 - loss: 1.1918e-04 - val_accuracy: 0.9263 - val_loss: 0.5037
# Epoch 2406/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step - accuracy: 1.0000 - loss: 1.1909e-04 - val_accuracy: 0.9263 - val_loss: 0.5037
# Epoch 2407/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step - accuracy: 1.0000 - loss: 1.1900e-04 - val_accuracy: 0.9263 - val_loss: 0.5037
# Epoch 2408/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - accuracy: 1.0000 - loss: 1.1891e-04 - val_accuracy: 0.9263 - val_loss: 0.5036
# Epoch 2409/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - accuracy: 1.0000 - loss: 1.1881e-04 - val_accuracy: 0.9263 - val_loss: 0.5036
# Epoch 2410/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - accuracy: 1.0000 - loss: 1.1872e-04 - val_accuracy: 0.9263 - val_loss: 0.5036
# Epoch 2411/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 825ms/step - accuracy: 1.0000 - loss: 1.1863e-04 - val_accuracy: 0.9263 - val_loss: 0.5035
# Epoch 2412/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 1.1854e-04 - val_accuracy: 0.9263 - val_loss: 0.5035
# Epoch 2413/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 1.1844e-04 - val_accuracy: 0.9263 - val_loss: 0.5035
# Epoch 2414/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 970ms/step - accuracy: 1.0000 - loss: 1.1835e-04 - val_accuracy: 0.9263 - val_loss: 0.5035
# Epoch 2415/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - accuracy: 1.0000 - loss: 1.1826e-04 - val_accuracy: 0.9263 - val_loss: 0.5034
# Epoch 2416/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step - accuracy: 1.0000 - loss: 1.1817e-04 - val_accuracy: 0.9263 - val_loss: 0.5034
# Epoch 2417/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - accuracy: 1.0000 - loss: 1.1808e-04 - val_accuracy: 0.9263 - val_loss: 0.5034
# Epoch 2418/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step - accuracy: 1.0000 - loss: 1.1799e-04 - val_accuracy: 0.9263 - val_loss: 0.5034
# Epoch 2419/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - accuracy: 1.0000 - loss: 1.1789e-04 - val_accuracy: 0.9263 - val_loss: 0.5033
# Epoch 2420/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - accuracy: 1.0000 - loss: 1.1780e-04 - val_accuracy: 0.9263 - val_loss: 0.5033
# Epoch 2421/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - accuracy: 1.0000 - loss: 1.1771e-04 - val_accuracy: 0.9263 - val_loss: 0.5033
# Epoch 2422/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step - accuracy: 1.0000 - loss: 1.1762e-04 - val_accuracy: 0.9263 - val_loss: 0.5033
# Epoch 2423/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step - accuracy: 1.0000 - loss: 1.1753e-04 - val_accuracy: 0.9263 - val_loss: 0.5032
# Epoch 2424/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step - accuracy: 1.0000 - loss: 1.1744e-04 - val_accuracy: 0.9263 - val_loss: 0.5032
# Epoch 2425/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step - accuracy: 1.0000 - loss: 1.1735e-04 - val_accuracy: 0.9263 - val_loss: 0.5032
# Epoch 2426/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step - accuracy: 1.0000 - loss: 1.1725e-04 - val_accuracy: 0.9263 - val_loss: 0.5032
# Epoch 2427/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 1.0000 - loss: 1.1716e-04 - val_accuracy: 0.9263 - val_loss: 0.5031
# Epoch 2428/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step - accuracy: 1.0000 - loss: 1.1707e-04 - val_accuracy: 0.9263 - val_loss: 0.5031
# Epoch 2429/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step - accuracy: 1.0000 - loss: 1.1698e-04 - val_accuracy: 0.9263 - val_loss: 0.5031
# Epoch 2430/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step - accuracy: 1.0000 - loss: 1.1689e-04 - val_accuracy: 0.9263 - val_loss: 0.5030
# Epoch 2431/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step - accuracy: 1.0000 - loss: 1.1680e-04 - val_accuracy: 0.9263 - val_loss: 0.5030
# Epoch 2432/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step - accuracy: 1.0000 - loss: 1.1671e-04 - val_accuracy: 0.9263 - val_loss: 0.5030
# Epoch 2433/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 1.1662e-04 - val_accuracy: 0.9263 - val_loss: 0.5030
# Epoch 2434/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 861ms/step - accuracy: 1.0000 - loss: 1.1653e-04 - val_accuracy: 0.9263 - val_loss: 0.5029
# Epoch 2435/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 814ms/step - accuracy: 1.0000 - loss: 1.1644e-04 - val_accuracy: 0.9263 - val_loss: 0.5029
# Epoch 2436/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step - accuracy: 1.0000 - loss: 1.1635e-04 - val_accuracy: 0.9263 - val_loss: 0.5029
# Epoch 2437/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - accuracy: 1.0000 - loss: 1.1626e-04 - val_accuracy: 0.9263 - val_loss: 0.5029
# Epoch 2438/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 1.0000 - loss: 1.1617e-04 - val_accuracy: 0.9263 - val_loss: 0.5028
# Epoch 2439/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - accuracy: 1.0000 - loss: 1.1608e-04 - val_accuracy: 0.9263 - val_loss: 0.5028
# Epoch 2440/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step - accuracy: 1.0000 - loss: 1.1599e-04 - val_accuracy: 0.9263 - val_loss: 0.5028
# Epoch 2441/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - accuracy: 1.0000 - loss: 1.1590e-04 - val_accuracy: 0.9263 - val_loss: 0.5028
# Epoch 2442/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step - accuracy: 1.0000 - loss: 1.1581e-04 - val_accuracy: 0.9263 - val_loss: 0.5027
# Epoch 2443/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step - accuracy: 1.0000 - loss: 1.1572e-04 - val_accuracy: 0.9263 - val_loss: 0.5027
# Epoch 2444/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step - accuracy: 1.0000 - loss: 1.1564e-04 - val_accuracy: 0.9263 - val_loss: 0.5027
# Epoch 2445/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - accuracy: 1.0000 - loss: 1.1555e-04 - val_accuracy: 0.9263 - val_loss: 0.5027
# Epoch 2446/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - accuracy: 1.0000 - loss: 1.1546e-04 - val_accuracy: 0.9263 - val_loss: 0.5026
# Epoch 2447/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step - accuracy: 1.0000 - loss: 1.1537e-04 - val_accuracy: 0.9263 - val_loss: 0.5026
# Epoch 2448/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step - accuracy: 1.0000 - loss: 1.1528e-04 - val_accuracy: 0.9263 - val_loss: 0.5026
# Epoch 2449/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - accuracy: 1.0000 - loss: 1.1519e-04 - val_accuracy: 0.9263 - val_loss: 0.5026
# Epoch 2450/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - accuracy: 1.0000 - loss: 1.1510e-04 - val_accuracy: 0.9263 - val_loss: 0.5025
# Epoch 2451/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 1.0000 - loss: 1.1501e-04 - val_accuracy: 0.9263 - val_loss: 0.5025
# Epoch 2452/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step - accuracy: 1.0000 - loss: 1.1493e-04 - val_accuracy: 0.9263 - val_loss: 0.5025
# Epoch 2453/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step - accuracy: 1.0000 - loss: 1.1484e-04 - val_accuracy: 0.9263 - val_loss: 0.5024
# Epoch 2454/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step - accuracy: 1.0000 - loss: 1.1475e-04 - val_accuracy: 0.9263 - val_loss: 0.5024
# Epoch 2455/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step - accuracy: 1.0000 - loss: 1.1466e-04 - val_accuracy: 0.9263 - val_loss: 0.5024
# Epoch 2456/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step - accuracy: 1.0000 - loss: 1.1457e-04 - val_accuracy: 0.9263 - val_loss: 0.5024
# Epoch 2457/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step - accuracy: 1.0000 - loss: 1.1449e-04 - val_accuracy: 0.9263 - val_loss: 0.5023
# Epoch 2458/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 1.0000 - loss: 1.1440e-04 - val_accuracy: 0.9263 - val_loss: 0.5023
# Epoch 2459/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step - accuracy: 1.0000 - loss: 1.1431e-04 - val_accuracy: 0.9263 - val_loss: 0.5023
# Epoch 2460/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step - accuracy: 1.0000 - loss: 1.1422e-04 - val_accuracy: 0.9263 - val_loss: 0.5023
# Epoch 2461/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step - accuracy: 1.0000 - loss: 1.1414e-04 - val_accuracy: 0.9263 - val_loss: 0.5022
# Epoch 2462/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step - accuracy: 1.0000 - loss: 1.1405e-04 - val_accuracy: 0.9263 - val_loss: 0.5022
# Epoch 2463/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step - accuracy: 1.0000 - loss: 1.1396e-04 - val_accuracy: 0.9263 - val_loss: 0.5022
# Epoch 2464/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step - accuracy: 1.0000 - loss: 1.1387e-04 - val_accuracy: 0.9263 - val_loss: 0.5022
# Epoch 2465/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step - accuracy: 1.0000 - loss: 1.1379e-04 - val_accuracy: 0.9263 - val_loss: 0.5021
# Epoch 2466/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step - accuracy: 1.0000 - loss: 1.1370e-04 - val_accuracy: 0.9263 - val_loss: 0.5021
# Epoch 2467/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - accuracy: 1.0000 - loss: 1.1361e-04 - val_accuracy: 0.9263 - val_loss: 0.5021
# Epoch 2468/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step - accuracy: 1.0000 - loss: 1.1353e-04 - val_accuracy: 0.9263 - val_loss: 0.5021
# Epoch 2469/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step - accuracy: 1.0000 - loss: 1.1344e-04 - val_accuracy: 0.9263 - val_loss: 0.5020
# Epoch 2470/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - accuracy: 1.0000 - loss: 1.1335e-04 - val_accuracy: 0.9263 - val_loss: 0.5020
# Epoch 2471/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - accuracy: 1.0000 - loss: 1.1327e-04 - val_accuracy: 0.9263 - val_loss: 0.5020
# Epoch 2472/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step - accuracy: 1.0000 - loss: 1.1318e-04 - val_accuracy: 0.9263 - val_loss: 0.5020
# Epoch 2473/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step - accuracy: 1.0000 - loss: 1.1309e-04 - val_accuracy: 0.9263 - val_loss: 0.5019
# Epoch 2474/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step - accuracy: 1.0000 - loss: 1.1301e-04 - val_accuracy: 0.9263 - val_loss: 0.5019
# Epoch 2475/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 798ms/step - accuracy: 1.0000 - loss: 1.1292e-04 - val_accuracy: 0.9263 - val_loss: 0.5019
# Epoch 2476/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 1.1284e-04 - val_accuracy: 0.9263 - val_loss: 0.5019
# Epoch 2477/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 790ms/step - accuracy: 1.0000 - loss: 1.1275e-04 - val_accuracy: 0.9263 - val_loss: 0.5018
# Epoch 2478/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 811ms/step - accuracy: 1.0000 - loss: 1.1266e-04 - val_accuracy: 0.9263 - val_loss: 0.5018
# Epoch 2479/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 851ms/step - accuracy: 1.0000 - loss: 1.1258e-04 - val_accuracy: 0.9263 - val_loss: 0.5018
# Epoch 2480/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step - accuracy: 1.0000 - loss: 1.1249e-04 - val_accuracy: 0.9263 - val_loss: 0.5018
# Epoch 2481/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step - accuracy: 1.0000 - loss: 1.1241e-04 - val_accuracy: 0.9263 - val_loss: 0.5017
# Epoch 2482/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - accuracy: 1.0000 - loss: 1.1232e-04 - val_accuracy: 0.9263 - val_loss: 0.5017
# Epoch 2483/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step - accuracy: 1.0000 - loss: 1.1224e-04 - val_accuracy: 0.9263 - val_loss: 0.5017
# Epoch 2484/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step - accuracy: 1.0000 - loss: 1.1215e-04 - val_accuracy: 0.9263 - val_loss: 0.5017
# Epoch 2485/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - accuracy: 1.0000 - loss: 1.1206e-04 - val_accuracy: 0.9263 - val_loss: 0.5016
# Epoch 2486/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - accuracy: 1.0000 - loss: 1.1198e-04 - val_accuracy: 0.9263 - val_loss: 0.5016
# Epoch 2487/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step - accuracy: 1.0000 - loss: 1.1189e-04 - val_accuracy: 0.9263 - val_loss: 0.5016
# Epoch 2488/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step - accuracy: 1.0000 - loss: 1.1181e-04 - val_accuracy: 0.9263 - val_loss: 0.5016
# Epoch 2489/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step - accuracy: 1.0000 - loss: 1.1172e-04 - val_accuracy: 0.9263 - val_loss: 0.5015
# Epoch 2490/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step - accuracy: 1.0000 - loss: 1.1166e-04 - val_accuracy: 0.9263 - val_loss: 0.5015
# Epoch 2491/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step - accuracy: 1.0000 - loss: 1.1157e-04 - val_accuracy: 0.9263 - val_loss: 0.5015
# Epoch 2492/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step - accuracy: 1.0000 - loss: 1.1149e-04 - val_accuracy: 0.9263 - val_loss: 0.5015
# Epoch 2493/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - accuracy: 1.0000 - loss: 1.1140e-04 - val_accuracy: 0.9263 - val_loss: 0.5014
# Epoch 2494/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 1.0000 - loss: 1.1132e-04 - val_accuracy: 0.9263 - val_loss: 0.5014
# Epoch 2495/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step - accuracy: 1.0000 - loss: 1.1124e-04 - val_accuracy: 0.9263 - val_loss: 0.5014
# Epoch 2496/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step - accuracy: 1.0000 - loss: 1.1115e-04 - val_accuracy: 0.9263 - val_loss: 0.5014
# Epoch 2497/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step - accuracy: 1.0000 - loss: 1.1107e-04 - val_accuracy: 0.9263 - val_loss: 0.5013
# Epoch 2498/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 854ms/step - accuracy: 1.0000 - loss: 1.1098e-04 - val_accuracy: 0.9263 - val_loss: 0.5013
# Epoch 2499/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 882ms/step - accuracy: 1.0000 - loss: 1.1090e-04 - val_accuracy: 0.9263 - val_loss: 0.5013
# Epoch 2500/2500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step - accuracy: 1.0000 - loss: 1.1082e-04 - val_accuracy: 0.9263 - val_loss: 0.5013

# %%
# First version of the model is a NN with two LSTM layers similar to the one
# in the article, however, with Unidirectional layers as I do not see the need
# for bidirectionality in solving this problem as it seems to be the time
# decay of spectral components should suffice to say which drum is in question

# Define the LSTM model
model = Sequential()
model.add(SimpleRNN(units=250, input_shape=(1,X.shape[2]), return_sequences=True))  # n_timesteps is the number of time samples, n_features is the number of frequency bins
#model.add(LSTM(units=100, return_sequences=True, activation='tanh'))  # n_timesteps is the number of time samples, n_features is the number of frequency bins
model.add(TimeDistributed(Dense(units=5, activation='softmax')))  # num_classes is the number of drum types

# Early stop is used to make sure model is not overfitting. If 'val_loss' is not improved within 10 epochs (patience=10), the training is automaticlly stopped.
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=1, mode='auto')

# Define the optimizer with a specific learning rate
optimizer = Adam(learning_rate=0.01)  # Adjust the learning rate as needed
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
model.fit(X, Y,  validation_data=(X_val,Y_val), verbose=1,callbacks=[early], epochs=200 )
# Out:
# Epoch 1/200
# 212/212 [==============================] - 10s 20ms/step - loss: 2.0835 - accuracy: 0.2092 - val_loss: 2.8270 - val_accuracy: 0.1073
# Epoch 2/200
# 212/212 [==============================] - 3s 15ms/step - loss: 1.9040 - accuracy: 0.2137 - val_loss: 1.7436 - val_accuracy: 0.1610
# Epoch 3/200
# 212/212 [==============================] - 2s 10ms/step - loss: 2.0694 - accuracy: 0.2183 - val_loss: 2.2839 - val_accuracy: 0.1610
# Epoch 4/200
# 212/212 [==============================] - 3s 14ms/step - loss: 1.9553 - accuracy: 0.2266 - val_loss: 3.0431 - val_accuracy: 0.1073
# Epoch 5/200
# 212/212 [==============================] - 2s 9ms/step - loss: 2.0545 - accuracy: 0.2205 - val_loss: 1.8931 - val_accuracy: 0.1414
# Epoch 6/200
# 212/212 [==============================] - 2s 8ms/step - loss: 2.0861 - accuracy: 0.2052 - val_loss: 1.7620 - val_accuracy: 0.1610
# Epoch 7/200
# 212/212 [==============================] - 2s 8ms/step - loss: 2.0408 - accuracy: 0.2041 - val_loss: 2.0630 - val_accuracy: 0.1610
# Epoch 8/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.9342 - accuracy: 0.2146 - val_loss: 2.2706 - val_accuracy: 0.1073
# Epoch 9/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.9905 - accuracy: 0.2170 - val_loss: 2.8515 - val_accuracy: 0.1073
# Epoch 10/200
# 212/212 [==============================] - 2s 10ms/step - loss: 2.0032 - accuracy: 0.2149 - val_loss: 2.3943 - val_accuracy: 0.1610
# Epoch 11/200
# 212/212 [==============================] - 3s 14ms/step - loss: 1.8733 - accuracy: 0.2103 - val_loss: 1.9953 - val_accuracy: 0.1610
# Epoch 12/200
# 212/212 [==============================] - 2s 8ms/step - loss: 2.0060 - accuracy: 0.2131 - val_loss: 2.3365 - val_accuracy: 0.1610
# Epoch 13/200
# 212/212 [==============================] - 2s 8ms/step - loss: 2.0552 - accuracy: 0.2115 - val_loss: 1.6956 - val_accuracy: 0.1610
# Epoch 14/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9266 - accuracy: 0.2112 - val_loss: 2.4638 - val_accuracy: 0.1073
# Epoch 15/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9191 - accuracy: 0.2024 - val_loss: 2.2769 - val_accuracy: 0.1610
# Epoch 16/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9811 - accuracy: 0.2177 - val_loss: 1.7968 - val_accuracy: 0.1610
# Epoch 17/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.9118 - accuracy: 0.2074 - val_loss: 1.6367 - val_accuracy: 0.1610
# Epoch 18/200
# 212/212 [==============================] - 3s 13ms/step - loss: 2.0303 - accuracy: 0.2148 - val_loss: 1.6135 - val_accuracy: 0.1610
# Epoch 19/200
# 212/212 [==============================] - 2s 11ms/step - loss: 2.0302 - accuracy: 0.2062 - val_loss: 1.8445 - val_accuracy: 0.1610
# Epoch 20/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.9426 - accuracy: 0.2103 - val_loss: 2.2906 - val_accuracy: 0.1610
# Epoch 21/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9858 - accuracy: 0.2164 - val_loss: 2.0366 - val_accuracy: 0.1414
# Epoch 22/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9401 - accuracy: 0.2159 - val_loss: 1.5796 - val_accuracy: 0.4293
# Epoch 23/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9592 - accuracy: 0.2074 - val_loss: 2.3430 - val_accuracy: 0.1610
# Epoch 24/200
# 212/212 [==============================] - 2s 8ms/step - loss: 2.0462 - accuracy: 0.2152 - val_loss: 1.7088 - val_accuracy: 0.1414
# Epoch 25/200
# 212/212 [==============================] - 3s 13ms/step - loss: 2.0422 - accuracy: 0.2100 - val_loss: 2.3009 - val_accuracy: 0.1073
# Epoch 26/200
# 212/212 [==============================] - 2s 11ms/step - loss: 2.0589 - accuracy: 0.2112 - val_loss: 1.6337 - val_accuracy: 0.4293
# Epoch 27/200
# 212/212 [==============================] - 2s 8ms/step - loss: 2.0055 - accuracy: 0.2130 - val_loss: 1.7253 - val_accuracy: 0.1610
# Epoch 28/200
# 212/212 [==============================] - 2s 8ms/step - loss: 2.0190 - accuracy: 0.2081 - val_loss: 2.2232 - val_accuracy: 0.1610
# Epoch 29/200
# 212/212 [==============================] - 2s 8ms/step - loss: 2.0213 - accuracy: 0.2097 - val_loss: 2.3005 - val_accuracy: 0.1414
# Epoch 30/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9007 - accuracy: 0.2215 - val_loss: 1.7723 - val_accuracy: 0.1610
# Epoch 31/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.9534 - accuracy: 0.2093 - val_loss: 2.0357 - val_accuracy: 0.4293
# Epoch 32/200
# 212/212 [==============================] - 3s 12ms/step - loss: 2.0430 - accuracy: 0.2111 - val_loss: 1.5713 - val_accuracy: 0.4293
# Epoch 33/200
# 212/212 [==============================] - 3s 12ms/step - loss: 1.9839 - accuracy: 0.2087 - val_loss: 1.7813 - val_accuracy: 0.1610
# Epoch 34/200
# 212/212 [==============================] - 2s 9ms/step - loss: 2.0489 - accuracy: 0.2133 - val_loss: 1.8372 - val_accuracy: 0.1610
# Epoch 35/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9907 - accuracy: 0.2176 - val_loss: 2.1890 - val_accuracy: 0.1610
# Epoch 36/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9719 - accuracy: 0.2189 - val_loss: 1.6730 - val_accuracy: 0.1610
# Epoch 37/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.9534 - accuracy: 0.2050 - val_loss: 1.8642 - val_accuracy: 0.4293
# Epoch 38/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.8896 - accuracy: 0.2139 - val_loss: 1.9288 - val_accuracy: 0.1073
# Epoch 39/200
# 212/212 [==============================] - 3s 12ms/step - loss: 2.0241 - accuracy: 0.2074 - val_loss: 3.3037 - val_accuracy: 0.1073
# Epoch 40/200
# 212/212 [==============================] - 3s 13ms/step - loss: 2.0397 - accuracy: 0.2106 - val_loss: 1.6842 - val_accuracy: 0.1610
# Epoch 41/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.9260 - accuracy: 0.2086 - val_loss: 1.9164 - val_accuracy: 0.1073
# Epoch 42/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.8805 - accuracy: 0.2105 - val_loss: 1.8970 - val_accuracy: 0.1414
# Epoch 43/200
# 212/212 [==============================] - 2s 9ms/step - loss: 1.9493 - accuracy: 0.2186 - val_loss: 2.3536 - val_accuracy: 0.1073
# Epoch 44/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9817 - accuracy: 0.2044 - val_loss: 2.6535 - val_accuracy: 0.1073
# Epoch 45/200
# 212/212 [==============================] - 2s 8ms/step - loss: 1.9565 - accuracy: 0.2130 - val_loss: 2.4804 - val_accuracy: 0.1610
# Epoch 46/200
# 212/212 [==============================] - 2s 12ms/step - loss: 1.9656 - accuracy: 0.2099 - val_loss: 1.8758 - val_accuracy: 0.1636
# Epoch 47/200
# 212/212 [==============================] - 3s 13ms/step - loss: 1.9296 - accuracy: 0.2146 - val_loss: 2.2620 - val_accuracy: 0.1073
# Epoch 47: early stopping

# %%
# Literal copy from the article - DO NOT ANALYSE THIS TOO MUCH

'''###### TRAIN 2: Bidirectional LSTM - 2 layers - 500 unis per layer ######'''
# Define Hyperparameter
number_units = 250
number_layers = 2
number_classes = 5
num_epochs = 200
batch_size = 40


# Define the optimizer with a specific learning rate
optimizer2 = Adam(learning_rate=0.01)  # Adjust the learning rate as needed

print ('Build model...')
# sequential methodology allows you to easily stack layers into your network without worrying too much about all the tensors
model2 = Sequential()

model2.add(Bidirectional(LSTM(units=number_units, input_shape=(X.shape[1], X.shape[2]), return_sequences=True)))
# Add two BiLSTM hidden layers
model.add(Bidirectional(LSTM(number_units, return_sequences=True, activation='tanh')))
# a dropout layer to prevent overfitting.
model.add(Dropout(0.25))

print("Adding classification layer")
# TimeDistributed adds an independent layer for each time step in the recurrent model.
# The TimeDistributed layer creates a vector of length equal to the number of features outputted from the previous layer.
model2.add(TimeDistributed(Dense(number_classes)))
model2.add(Activation('sigmoid'))

# Compile model: binary crossentroypy are used as loss and metrics. The metrics are used to check the improvement of model during training
model2.compile(loss='categorical_crossentropy', optimizer=optimizer2, metrics=['accuracy'])
# Out:
# Build model...
# Adding classification layer

# %%
D = librosa.stft(audio_snare)
magnitude, phase = librosa.magphase(D)

# Convert magnitude to decibels
magnitude_db = librosa.amplitude_to_db(magnitude, ref=np.max)
magnitude_db = np.sum(magnitude_db.T,axis=0)
magnitude_db = magnitude_db.reshape(1,1,magnitude_db.shape[0])
print(magnitude_db.shape)


pred = model_FF.predict(magnitude_db)

#print(pred)

max_indices  = np.argmax(pred, axis=-1)
#print(max_indices)

# Create a one-hot representation for each sequence
one_hot_output = np.eye(pred.shape[-1])[max_indices]

#print(one_hot_output)

# Inverse transform the predicted classes to get the original class labels
predicted_class_names = encoder.inverse_transform(one_hot_output.reshape(one_hot_output.shape[1],one_hot_output.shape[2]))

print("Predicted class names:", predicted_class_names)
# Out:
# (1, 1, 1025)
# 1/1 [==============================] - 0s 70ms/step
# Predicted class names: [['toms']]

# %% [markdown]
# # Task
# Reconstruct an audio segment from `X_train` by converting its decibel spectrogram representation to linear magnitude, transposing it, and then applying the Griffin-Lim algorithm to generate a time-domain waveform. Finally, play the reconstructed audio. The reconstruction should use `n_fft = 2048`, `hop_length = 512`, and `sr = 22050`. Use the first 100 frames of `X_train` for this reconstruction.

# %% [markdown]
# ## Define Reconstruction Parameters
#
# ### Subtask:
# Determine the `hop_length` and `n_fft` used when `X_train` was generated in cell `DfVXjtltyTHi`. The `n_fft` is `N_FFT`, and since `hop_length` was not specified in `librosa.stft`, it defaulted to `N_FFT // 4`.

# %% [markdown]
# **Reasoning**:
# The subtask requires determining and printing the `n_fft`, `hop_length`, and `sr` values used during the STFT calculation. I will define `n_fft` as `N_FFT` (2048), calculate `hop_length` as `n_fft // 4`, and verify `sr` is `22050`, then print them.

# %%
n_fft_reconstruct = N_FFT
hop_length_reconstruct = n_fft_reconstruct // 4
sr_reconstruct = sr

print(f"N_FFT for reconstruction: {n_fft_reconstruct}")
print(f"Hop length for reconstruction: {hop_length_reconstruct}")
print(f"Sample rate (sr) for reconstruction: {sr_reconstruct}")
# Out:
# N_FFT for reconstruction: 2048
# Hop length for reconstruction: 512
# Sample rate (sr) for reconstruction: 22050

# %% [markdown]
# **Reasoning**:
# Now that the reconstruction parameters are confirmed, the next step is to prepare the spectrogram data from `X_train` for reconstruction. This involves selecting the first 100 frames of `X_train`, converting the decibel values back to linear magnitudes, and transposing the spectrogram to the format expected by `librosa.griffinlim` (frequency x time).

# %%
spectrogram_db = X_train[:100, :].T
spectrogram_linear = librosa.db_to_amplitude(spectrogram_db)
print(f"Shape of spectrogram_db: {spectrogram_db.shape}")
print(f"Shape of spectrogram_linear: {spectrogram_linear.shape}")
# Out:
# Shape of spectrogram_db: (1025, 100)
# Shape of spectrogram_linear: (1025, 100)

# %% [markdown]
# **Reasoning**:
# With the linear magnitude spectrogram prepared and reconstruction parameters defined, the next step is to apply the Griffin-Lim algorithm to synthesize the time-domain waveform from the spectrogram and then play the reconstructed audio.

# %%
audio_reconstructed = librosa.griffinlim(spectrogram_linear, hop_length=hop_length_reconstruct, n_fft=n_fft_reconstruct)

print(f"Shape of reconstructed audio: {audio_reconstructed.shape}")

# Play the reconstructed audio (requires IPython.display for Colab)
from IPython.display import Audio
Audio(audio_reconstructed, rate=sr_reconstruct)
# Out:
# Shape of reconstructed audio: (50688,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide the reconstructed audio segment for review.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The reconstructed audio segment was successfully generated and played for review.
#
# ### Data Analysis Key Findings
# *   The reconstruction parameters were identified as `N_FFT = 2048`, `hop_length = 512` (calculated as `N_FFT // 4`), and a sample rate (`sr`) of `22050`.
# *   The first 100 frames of the `X_train` decibel spectrogram were selected and transposed, resulting in a `spectrogram_db` with a shape of `(1025, 100)`.
# *   This decibel spectrogram was converted to a linear magnitude spectrogram (`spectrogram_linear`), maintaining the shape of `(1025, 100)`.
# *   The `librosa.griffinlim` algorithm successfully reconstructed the audio waveform, resulting in an `audio_reconstructed` array with a shape of `(50688,)`.
#
# ### Insights or Next Steps
# *   This reconstruction process can be utilized to reverse spectrogram modifications for applications such as audio enhancement or synthesis.
# *   Further analysis could involve comparing the reconstructed audio to the original audio to quantify reconstruction quality metrics.
